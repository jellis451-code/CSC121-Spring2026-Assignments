# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Team Profile Generator

# Function definition
def print_bio(name, age, goal):
    border = "*" * 25
    print(border)
    print(f"Name: {name}, Age: {age} Goal: {goal}")
    print(border)
    print()  # blank line for separation between profiles

# Program logic

# Call 1: Yourself
print_bio("Jordan", 22, "Learn Python")

# Call 2: Famous Person
print_bio("Ada Lovelace", 36, "Invent Computing")

# Call 3: Fictional Character
print_bio("Sherlock Holmes", 40, "Solve Crimes")
