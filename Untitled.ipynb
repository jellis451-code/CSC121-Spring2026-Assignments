# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. If age <= 12 or age >= 65:
#       price = 8
#    else:
#       price = 12
# 3. If hour < 17:
#       subtract 2 from price
# 4. Print the final price

# PROGRAM LOGIC
# 1. Ask user for age
# 2. Ask user for movie hour (24-hour format)
# 3. Call calculate_ticket(age, hour)
