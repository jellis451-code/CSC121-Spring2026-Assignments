# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PART 3: COMPLETION

# Print the total minutes in a 2-hour 45-minute movie with a label
print("Total minutes in movie:", 2 * 60 + 45)

# Print the years since the first computer bug in 1947 with a label
print("Years since first bug:", 2026 - 1947)

# Print the total cost of buying 7 Python textbooks at $35 each with a label
print("Total cost of books:", 7 * 35)
# Out:
# Total minutes in movie: 165
# Years since first bug: 79
# Total cost of books: 245
