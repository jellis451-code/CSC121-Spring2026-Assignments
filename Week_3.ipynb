# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments/blob/main/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================
# Professional Bio Generator
# ==============================

name = "Jayden Ellis"
goal = "build software applications"
birth_year = 2006
current_year = 2026

age = current_year - birth_year

border = "=" * 25

print(border)
print("My name is", name, "and I am", age, "years old.")
print("My goal is to", goal + ".")
print(border)
# Out:
# =========================
# My name is Jayden Ellis and I am 20 years old.
# My goal is to build software applications.
# =========================
