# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments/blob/main/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================
# Professional Bio Generator
# ==============================

# 1. Assign values to name, goal, birth_year, and current_year
# 2. Calculate age by subtracting birth_year from current_year
# 3. Create a border using string multiplication (25 characters)
# 4. Print the top border
# 5. Print the professional bio
# 6. Print the bottom border
